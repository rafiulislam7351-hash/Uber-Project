# %%
import pandas as pd

file_name=[
  {
    "json_file_name": "map_cancellation_reasons"
  },
  {
    "json_file_name": "map_cities"
  },
  {
    "json_file_name": "map_payment_methods"
  },
  {
    "json_file_name": "map_ride_statuses"
  },
  {
    "json_file_name": "map_vehicle_makes"
  },
  {
    "json_file_name": "map_vehicle_types"
  }
]

for json_file_name in file_name:

    url=f"https://rideinformation.blob.core.windows.net/bronze/ingestion/{json_file_name['json_file_name']}.json?sp=racwdlmeop&st=2026-09-23T09:31:12Z&se=2026-09-28T17:46:12Z&spr=https&sv=2026-02-06&sr=c&sig=VzXhINPlqYZfjGJ55YRxVW%2F3G%2FhI9tPrJbxjqNsV3O8%3D"

    df=pd.read_json(url)

    df_spark=spark.createDataFrame(df)
    
    # Writing data back to bronze layer

    df_spark.write.format("delta")\
            .mode("overwrite")\
            .option("overwriteSchema", "true")\
            .saveAsTable(f"uberdata.bronze.{json_file_name["json_file_name"]}")

# %%
url1=f"https://rideinformation.blob.core.windows.net/bronze/ingestion/bulk_rides.json?sp=racwdlmeop&st=2026-09-23T09:31:12Z&se=2026-09-28T17:46:12Z&spr=https&sv=2026-02-06&sr=c&sig=VzXhINPlqYZfjGJ55YRxVW%2F3G%2FhI9tPrJbxjqNsV3O8%3D"
df_br=pd.read_json(url1)
df_spark=spark.createDataFrame(df_br)
# Writing data back to bronze layer
if not spark.catalog.tableExists("uberdata.bronze.bulk_rides"):
    df_spark.write.format("delta")\
            .mode("overwrite")\
            .saveAsTable(f"uberdata.bronze.bulk_rides")
    print("This Table is fixed")
